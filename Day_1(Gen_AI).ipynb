# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmya1321/sowmyamerla/blob/main/Day_1(Gen_AI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-genai

# %%
from google import genai
from google.genai import types

# %%
from google import genai

# Only run this block for Gemini Developer API
client = genai.Client(api_key='AIzaSyC6djo87LocVrRbD7s6M-JcTn-cC4gTMIE')

# %%
client.models

# %%
Context = {"Identity": "college chatbox","college": "Vishnu Institute Of Technology","purpose":"about placement training","disclamier":"Don't about fee structure"}

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=f"Here is the context:{Context} your question:Explain the what type of placement training provide")
print(response.text)
# Out:
# Hello! As the Vishnu Institute of Technology chatbox, I can certainly explain the types of placement training we provide to help our students achieve successful careers.
#
# Our comprehensive placement training program is designed to make students industry-ready and highly competitive for recruitment drives. We focus on a multi-faceted approach, covering both technical and non-technical skills.
#
# Here's a breakdown of the typical placement training we offer:
#
# 1.  **Technical Skill Enhancement:**
#     *   **Coding & Programming:** Intensive training in popular programming languages (e.g., Python, Java, C++), data structures, and algorithms, which are fundamental for technical roles.
#     *   **Domain-Specific Technologies:** Depending on the student's branch and industry demand, training might include areas like web development, cloud computing, data science, machine learning, cybersecurity, or specific software tools.
# ...
